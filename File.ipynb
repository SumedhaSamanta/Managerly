# %%
import sqlite3
import webbrowser
inventory_management_system=sqlite3.connect('inventory_management_system.db')
try:
    inventory_management_system.execute('''CREATE TABLE user_cred (user_name text, emp_id real UNIQUE, password text)''')
except Exception as e:
    print(e)
    
try:
    inventory_management_system.execute('''CREATE TABLE inventory (Item_id INTEGER UNIQUE,Item_name text UNIQUE,Item_quantity INTEGER)''')
except Exception as e:
    print(e)
# Out:
# table user_cred already exists
# table inventory already exists

# %%
import sqlite3

# log in backend
def check(name,emp_id,password):
    inventory_management_system=sqlite3.connect('inventory_management_system.db')
    cursor=inventory_management_system.cursor()
    cursor.execute("SELECT * FROM user_cred WHERE user_name=? AND emp_id=? AND password=?",(name,emp_id,password))
    #cursor.execute("SELECT * FROM user_cred")
    rows = cursor.fetchall()
    if(rows==[]):
        return False
    else:
        return True
    
        
def signup(name,emp_id,password):
    try:
        inventory_management_system=sqlite3.connect('inventory_management_system.db')
        inventory_management_system.execute("INSERT INTO user_cred VALUES (?,?,?)",(name,emp_id,password))
        print("Signup successful!!!")
        inventory_management_system.commit()
        return True
    except:
        print("incorrect details. please re-enter")
        return False
        
def signin(name,emp_id,password):
    try:
        if(check(name,emp_id,password)):
            print("Log in success")
            return True
        else:
            print(1/0)
    except:
        print("incorrect details. please re-enter")
        return False
        


def reset_password(name,emp_id,password):
    inventory_management_system=sqlite3.connect('inventory_management_system.db')
    cursor=inventory_management_system.cursor()
    cursor.execute("SELECT * FROM user_cred WHERE user_name=? AND emp_id=?",(name,emp_id))
    rows = cursor.fetchall()
    if(rows==[]):
        print("record not found")
        return False
    else:
        #print("enter new password")
        #password=input()
        #cursor=inventory_management_system.cursor()
        inventory_management_system.execute("UPDATE user_cred SET password=? WHERE emp_id=? AND user_name=?",(password,emp_id,name))
        inventory_management_system.commit()
        print("change successfull")
        return True
    #signin()
        
#backend of inventry system
def add_inventory(Item_id,name,quantity):
    try:
        inventory_management_system=sqlite3.connect('inventory_management_system.db')
        inventory_management_system.execute("INSERT INTO inventory VALUES (?,?,?)",(Item_id,name,quantity))
        print("Item successfully added")
        inventory_management_system.commit()
        return True
    except:
        print("incorrect details. please re-enter")
        return False
    
def sale(Item_id,name,quantity):
    inventory_management_system=sqlite3.connect('inventory_management_system.db')
    cursor=inventory_management_system.cursor()
    cursor.execute("SELECT * FROM inventory WHERE Item_id=? AND Item_name=?",(Item_id,name))
    rows = cursor.fetchall()
    if(rows==[]):
        print("record not found. item either finished or never existed")
        return False
    else:
        rows=list(rows)
        print(rows,"is rows")
        if(rows[0][2]-quantity<0):
            print("insufficent")
            inventory_management_system.execute("DELETE FROM inventory WHERE Item_id=?",(Item_id,))
            inventory_management_system.commit()
            return False
        else:
            inventory_management_system.execute("UPDATE inventory SET Item_quantity=? WHERE Item_id=?",(rows[0][2]-quantity,Item_id))
            print("change successfull")
            if(rows[0][2]-quantity==0):
                print("item finished")
                inventory_management_system.execute("DELETE FROM inventory WHERE Item_id=?",(Item_id,))
            inventory_management_system.commit()
            return True
        
def check_inventory():
    inventory_management_system=sqlite3.connect('inventory_management_system.db')
    cursor=inventory_management_system.cursor()
    cursor.execute("SELECT * FROM inventory")
    rows = cursor.fetchall()
    print(rows)
    
    
def destroy(root):
    root.destroy()
    
def nothing():
    pass

# %%
#running the software after log in
from tkinter import *

def check_fields(name,empid,password):
    if(name=="User Name" or name=="" or empid=="ID" or empid=="" or password=="" or password=="Password"):
        popup("ERROR: Not all Fields filled")
        return False
    else:
        return True
    
def viewInventory_click():
    print("View Inventory clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="INVENTORY", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def addToInventory_click():
    print("Add To Inventory clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="ADD TO INVENTORY", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def placeOrder_click():
    print("Place Order clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="PLACE ORDER", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def sale_click():
    print("Sale clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="SALE", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def statistics_click():
    print("Statistics clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="STATISTICS", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def help_click():
    print("Help clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)

    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)

    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)

    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)

    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)

    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)

    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)

    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 490, window=help_button)

    Window_name=Label(window, text="HELP", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)


    name_=Label(window, text="Account Details: "+name+"-X0"+ str(empid), font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
    top.create_window(480, 190, window=name_)

    text1="This is the Help section of the inventory management system."
    info1=Label(window, text=text1, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=50,height=1)
    top.create_window(626, 243, window=info1)


    url = "https://themanagerly.8b.io"

    def openweb():
        webbrowser.open(url,new=1)
    button1 = Button(window, text = "Click Here",command=openweb)
    top.create_window(388, 308, window=button1)

    text2="In case of Technical Assistance"
    info2=Label(window, text=text2, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
    top.create_window(600, 308, window=info2)

    button2 = Button(window, text = "Click Here",command=openweb)
    top.create_window(388, 365,window=button2)

    text3="To Report a Problem"
    info3=Label(window, text=text3, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
    top.create_window(600, 365, window=info3)

    window.mainloop()
    
    
def yourAccount_click():
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="YOUR ACCOUNT DETAILS", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    name_=Label(window, text="Name: "+name, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=15,height=1)
    top.create_window(680, 200, window=name_)
    
    empid_=Label(window, text="ID  : "+str(empid), font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=15,height=1)
    top.create_window(680, 250, window=empid_)
    
    window.mainloop()


def correct(n,id_):
    global name
    global empid
    name=n
    empid=id_
    yourAccount_click()
    
def signin_click():
    name=search_name.get()
    empid=search_empid.get()
    password=search_password.get()
    
    if(check_fields(name,empid,password)):
        flag=signin(name,empid,password)
        print(flag)
        if(flag==True):
            #popup("SUCCESSFUL")
            root.destroy() 
            correct(name,empid)
        else:
            popup("ERROR: Incorrect Details. Please Re-enter")

def signup_click():
    name=search_name.get()
    empid=search_empid.get()
    password=search_password.get()
    if(check_fields(name,empid,password)):    
        flag=signup(name,empid,password)
        if(flag==True):
            popup("SUCCESSFUL")
        else:
            popup("ERROR: Incorrect Details or Pre-existing Record")

def popup(msg):
    root=Tk()
    root.geometry("300x50")
    root.title("Notification")
    myLabel=Label(root, text=msg)
    myLabel.pack()
    root.mainloop()
    
def reset_click():
    name=search_name.get()
    empid=search_empid.get()
    try:
        password=search_password.get()
        if(password==''):
            popup("Enter new Password in the Password field")
        else:
            if(check_fields(name,empid,password)):    
                flag=reset_password(name,empid,password)
                if(flag==True):
                    popup("SUCCESSFUL")
                else:
                    popup("ERROR: Incorrect Details. Please Re-enter")

    except:
        print("ok")

# %%
#the Running function - Log in-signup

from tkinter import *


root=Tk()
root.config(bg="white")
root.geometry("600x600")
root.title("The Managerly")

frame=Frame(root)
frame.grid(row=0,column=0,sticky=NE)
top=Canvas(frame,width=600,height=600,bg="black")
top.grid(row=0,column=0)
back_wall=PhotoImage(file="main_2.png")
top.create_image(300,300,image=back_wall)


T=Label(frame, text='The Managerly', font=('Zebrazil', 35), bg='white', fg='black', bd=0)
top.create_window(288.5, 130, window=T)

search_name=Entry(frame, width=15, font=('Zebrazil', 25), bg='grey20', fg='white', bd=0,borderwidth=7)
search_name.insert(0,"User Name")
top.create_window(288.5, 220, window=search_name)

search_empid=Entry(frame, width=10, font=('Zebrazil', 15), bg='grey20', fg='white', bd=0,borderwidth=7)
search_empid.insert(1,"ID")
top.create_window(215, 290, window=search_empid)


search_password=Entry(frame, width=12, font=('Zebrazil', 15), bg='grey20', fg='white', bd=0,borderwidth=7)
search_password.insert(2,"Password")
top.create_window(353, 290, window=search_password)

signin_button=Button(root,text="Sign in",command=signin_click)
top.create_window(260, 355, window=signin_button)

signup_button=Button(root,text="Sign up",command=signup_click)
top.create_window(310, 355, window=signup_button)

reset_button=Button(root,text="reset password",command=reset_click)
top.create_window(286, 390, window=reset_button)

root.mainloop()

def check_fields(name,empid,password):
    if(name=="User Name" or name=="" or empid=="ID" or empid=="" or password=="" or password=="Password"):
        popup("ERROR: Not all Fields filled")
        return False
    else:
        return True
    
def viewInventory_click():
    print("View Inventory clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="INVENTORY", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def addToInventory_click():
    print("Add To Inventory clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="ADD TO INVENTORY", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def placeOrder_click():
    print("Place Order clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="PLACE ORDER", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def sale_click():
    print("Sale clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="SALE", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def statistics_click():
    print("Statistics clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="STATISTICS", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def help_click():
    print("Help clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)

    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)

    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)

    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)

    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)

    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)

    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)

    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 490, window=help_button)

    Window_name=Label(window, text="HELP", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)


    name_=Label(window, text="Account Details: "+name+"-X0"+ str(empid), font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
    top.create_window(480, 190, window=name_)

    text1="This is the Help section of the inventory management system."
    info1=Label(window, text=text1, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=50,height=1)
    top.create_window(626, 243, window=info1)


    url = "https://themanagerly.8b.io"

    def openweb():
        webbrowser.open(url,new=1)
    button1 = Button(window, text = "Click Here",command=openweb)
    top.create_window(388, 308, window=button1)

    text2="In case of Technical Assistance"
    info2=Label(window, text=text2, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
    top.create_window(600, 308, window=info2)

    button2 = Button(window, text = "Click Here",command=openweb)
    top.create_window(388, 365,window=button2)

    text3="To Report a Problem"
    info3=Label(window, text=text3, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
    top.create_window(600, 365, window=info3)

    window.mainloop()

    
    
def yourAccount_click():
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="YOUR ACCOUNT DETAILS", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    name_=Label(window, text="Name: "+name, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=15,height=1)
    top.create_window(680, 200, window=name_)
    
    empid_=Label(window, text="ID  : "+str(empid), font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=15,height=1)
    top.create_window(680, 250, window=empid_)
    
    window.mainloop()


def correct(n,id_):
    global name
    global empid
    name=n
    empid=id_
    yourAccount_click()
    
def signin_click():
    name=search_name.get()
    empid=search_empid.get()
    password=search_password.get()
    
    if(check_fields(name,empid,password)):
        flag=signin(name,empid,password)
        print(flag)
        if(flag==True):
            #popup("SUCCESSFUL")
            root.destroy() 
            correct(name,empid)
        else:
            popup("ERROR: Incorrect Details. Please Re-enter")

def signup_click():
    name=search_name.get()
    empid=search_empid.get()
    password=search_password.get()
    if(check_fields(name,empid,password)):    
        flag=signup(name,empid,password)
        if(flag==True):
            popup("SUCCESSFUL")
        else:
            popup("ERROR: Incorrect Details or Pre-existing Record")

def popup(msg):
    root=Tk()
    root.geometry("300x50")
    root.title("Notification")
    myLabel=Label(root, text=msg)
    myLabel.pack()
    root.mainloop()
    
def reset_click():
    name=search_name.get()
    empid=search_empid.get()
    try:
        password=search_password.get()
        if(password==''):
            popup("Enter new Password in the Password field")
        else:
            if(check_fields(name,empid,password)):    
                flag=reset_password(name,empid,password)
                if(flag==True):
                    popup("SUCCESSFUL")
                else:
                    popup("ERROR: Incorrect Details. Please Re-enter")

    except:
        print("ok")
    
    
#to run code
# Out:
# Log in success
# True
# Help clicked
# Sale clicked
# Add To Inventory clicked
# View Inventory clicked
# Help clicked

# %%
def check_fields(name,empid,password):
    if(name=="User Name" or name=="" or empid=="ID" or empid=="" or password=="" or password=="Password"):
        popup("ERROR: Not all Fields filled")
        return False
    else:
        return True
    
def viewInventory_click():
    print("View Inventory clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="INVENTORY", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def addToInventory_click():
    print("Add To Inventory clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="ADD TO INVENTORY", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def placeOrder_click():
    print("Place Order clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="PLACE ORDER", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def sale_click():
    print("Sale clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="SALE", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def statistics_click():
    print("Statistics clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="STATISTICS", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()
    
def help_click():
    print("Help clicked")
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="HELP", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()

    
    
def yourAccount_click():
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=nothing)
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="YOUR ACCOUNT DETAILS", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    name_=Label(window, text="Name: "+name, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=15,height=1)
    top.create_window(680, 200, window=name_)
    
    empid_=Label(window, text="ID  : "+str(empid), font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=15,height=1)
    top.create_window(680, 250, window=empid_)
    
    window.mainloop()


def correct(n,id_):
    global name
    global empid
    name=n
    empid=id_
    yourAccount_click()
    
def signin_click():
    name=search_name.get()
    empid=search_empid.get()
    password=search_password.get()
    
    if(check_fields(name,empid,password)):
        flag=signin(name,empid,password)
        print(flag)
        if(flag==True):
            #popup("SUCCESSFUL")
            root.destroy() 
            correct(name,empid)
        else:
            popup("ERROR: Incorrect Details. Please Re-enter")

def signup_click():
    name=search_name.get()
    empid=search_empid.get()
    password=search_password.get()
    if(check_fields(name,empid,password)):    
        flag=signup(name,empid,password)
        if(flag==True):
            popup("SUCCESSFUL")
        else:
            popup("ERROR: Incorrect Details or Pre-existing Record")

def popup(msg):
    root=Tk()
    root.geometry("300x50")
    root.title("Notification")
    myLabel=Label(root, text=msg)
    myLabel.pack()
    root.mainloop()
    
def reset_click():
    name=search_name.get()
    empid=search_empid.get()
    try:
        password=search_password.get()
        if(password==''):
            popup("Enter new Password in the Password field")
        else:
            if(check_fields(name,empid,password)):    
                flag=reset_password(name,empid,password)
                if(flag==True):
                    popup("SUCCESSFUL")
                else:
                    popup("ERROR: Incorrect Details. Please Re-enter")

    except:
        print("ok")

# %%
def destroy(root):
    root.destroy()
    
def basic():
    window=Tk()
    window.config(bg="black")
    window.geometry("1536x864")
    window.title("The Managerly")
    frame=Frame(window)
    frame.grid(row=0,column=0,sticky=NE)
    top=Canvas(frame,width=1536,height=864,bg="black")
    top.grid(row=0,column=0)
    back_wall=PhotoImage(file="WindowMain2.png")
    top.create_image(768,432,image=back_wall)
    
    yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
    top.create_window(210, 130, window=yourAccount_button)
    
    viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
    top.create_window(210, 190 , window=viewInventory_button)
    
    addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
    top.create_window(210, 250, window=addToInventory_button)
    
    placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
    top.create_window(210, 310, window=placeOrder_button)
    
    sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
    top.create_window(210, 370, window=sale_button)
    
    statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
    top.create_window(210, 430, window=statistics_button)
    
    help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),help_click()])
    top.create_window(210, 490, window=help_button)
    
    Window_name=Label(window, text="TITLE", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
    top.create_window(680, 125, window=Window_name)
    
    window.mainloop()

# %%
from tkinter import *

print("Help clicked")
window=Tk()
window.config(bg="black")
window.geometry("1536x864")
window.title("The Managerly")
frame=Frame(window)
frame.grid(row=0,column=0,sticky=NE)
top=Canvas(frame,width=1536,height=864,bg="black")
top.grid(row=0,column=0)
back_wall=PhotoImage(file="WindowMain2.png")
top.create_image(768,432,image=back_wall)

yourAccount_button=Button(window,text="Your Account",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),yourAccount_click()])
top.create_window(210, 130, window=yourAccount_button)

viewInventory_button=Button(window,text="View Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),viewInventory_click()])
top.create_window(210, 190 , window=viewInventory_button)

addToInventory_button=Button(window,text="Add To Inventory",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),addToInventory_click()])
top.create_window(210, 250, window=addToInventory_button)

placeOrder_button=Button(window,text="Place Order",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),placeOrder_click()])
top.create_window(210, 310, window=placeOrder_button)

sale_button=Button(window,text="Sale",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),sale_click()])
top.create_window(210, 370, window=sale_button)

statistics_button=Button(window,text="Statistics",width=30,height=3,font=('Zebrazil', 10),command=lambda:[destroy(window),statistics_click()])
top.create_window(210, 430, window=statistics_button)

help_button=Button(window,text="Help",width=30,height=3,font=('Zebrazil', 10),command=nothing)
top.create_window(210, 490, window=help_button)

Window_name=Label(window, text="HELP", font=('Zebrazil', 20,'bold'), bg='white', fg='black', bd=0,width=30,height=1)
top.create_window(680, 125, window=Window_name)


name_=Label(window, text="Account Details: "+name+"-X0"+ str(empid), font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
top.create_window(480, 190, window=name_)

text1="This is the Help section of the inventory management system."
info1=Label(window, text=text1, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=50,height=1)
top.create_window(626, 243, window=info1)


url = "https://themanagerly.8b.io"

def openweb():
    webbrowser.open(url,new=1)
button1 = Button(window, text = "Click Here",command=openweb)
top.create_window(388, 308, window=button1)

text2="In case of Technical Assistance"
info2=Label(window, text=text2, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
top.create_window(600, 308, window=info2)

button2 = Button(window, text = "Click Here",command=openweb)
top.create_window(388, 365,window=button2)

text3="To Report a Problem"
info3=Label(window, text=text3, font=('Zebrazil', 15), bg='white', fg='black', bd=0,width=25,height=1)
top.create_window(600, 365, window=info3)

window.mainloop()
# Out:
# Help clicked
# Statistics clicked
# Sale clicked
# Help clicked
